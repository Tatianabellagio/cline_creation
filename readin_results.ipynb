# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
casual_loci = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/results/causal_loci/causal_loci_78ea6d6b.txt',header=None)[0]

# %%
clines = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/results/clines/clines_df_78ea6d6b.csv')

# %%
clines = clines.sort_values('P_Value').reset_index().drop(['index', 'Unnamed: 0'],axis=1).reset_index().rename(columns={'index':'most_sign'})

# %%
clines[clines['SNP'].isin(casual_loci)]
# Out:
#     most_sign     SNP      Slope       P_Value  Color
# 0           0  306157  69.617647  7.730718e-10  green
# 1           1  187249  68.330882  1.379132e-09  green
# 2           2   27327  70.622549  1.878535e-09  green
# 3           3  315313  73.549020  4.037666e-09  green
# 4           4  308123  63.235294  6.853500e-09  green
# 5           5  206138  56.669118  6.584881e-08  green
# 7           7  431429  57.000000  6.344499e-07  green
# 12         12  158906  55.845588  2.958496e-06  green
# 16         16   49003  61.767157  5.275795e-06  green
# 53         53  403914  41.399510  1.071458e-04  green

# %%
most_sign = clines.sort_values('P_Value')

# %%
most_sign[most_sign['SNP'].isin(casual_loci)]
# Out:
#      Unnamed: 0     SNP      Slope       P_Value  Color
# 526        1805  306157  69.617647  7.730718e-10  green
# 334        1117  187249  68.330882  1.379132e-09  green
# 35          140   27327  70.622549  1.878535e-09  green
# 544        1846  315313  73.549020  4.037666e-09  green
# 528        1812  308123  63.235294  6.853500e-09  green
# 376        1237  206138  56.669118  6.584881e-08  green
# 757        2527  431429  57.000000  6.344499e-07  green
# 297         969  158906  55.845588  2.958496e-06  green
# 77          266   49003  61.767157  5.275795e-06  green

# %%
pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/fitnesses.txt', sep='\t', header=None)
# Out:
#           0         1        2        3        4        5        6        7   \
# 0    8.20715  10.06430  7.64158  8.56973  8.65274  8.02088  8.56348  7.01962
# 1    8.52268  10.33640  7.80874  8.69537  8.82071  8.23588  8.77257  7.38676
# 2    8.81459  10.55910  7.96761  8.79745  8.96710  8.43846  8.95373  7.74244
# 3    9.08051  10.72900  8.11706  8.87652  9.09052  8.62711  9.10519  8.08252
# 4    9.31839  10.84410  8.25560  8.93328  9.18963  8.80007  9.22548  8.40294
# 5    9.52654  10.90320  8.38151  8.96842  9.26315  8.95541  9.31342  8.69975
# 6    9.70353  10.90620  8.49282  8.98264  9.30991  9.09099  9.36817  8.96924
# 7    9.84823  10.85440  8.58739  8.97658  9.32882  9.20458  9.38925  9.20803
# 8    9.95976  10.74960  8.66302  8.95075  9.31895  9.29395  9.37658  9.41311
# 9   10.03740  10.59480  8.71748  8.90555  9.27953  9.35688  9.33046  9.58193
# 10  10.08070  10.39370  8.74866  8.84121  9.21005  9.39133  9.25159  9.71248
# ...

# %%
fit1
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.968625  0.979292  0.970562  0.974793  0.967214  0.971223  0.972599
# 1   0.970750  0.980134  0.973117  0.976009  0.969421  0.972923  0.974357
# 2   0.972592  0.980685  0.975387  0.976937  0.971346  0.974339  0.975829
# 3   0.974150  0.980946  0.977371  0.977578  0.972988  0.975469  0.977015
# 4   0.975423  0.980915  0.979067  0.977931  0.974346  0.976313  0.977912
# 5   0.976410  0.980593  0.980474  0.977995  0.975418  0.976869  0.978522
# 6   0.977110  0.979980  0.981589  0.977770  0.976204  0.977138  0.978841
# 7   0.977521  0.979076  0.982413  0.977257  0.976704  0.977119  0.978872
# 8   0.977645  0.977883  0.982944  0.976456  0.976915  0.976813  0.978613
# 9   0.977480  0.976401  0.983181  0.975367  0.976839  0.976218  0.978065
# 10  0.977026  0.974633  0.983126  0.973993  0.976476  0.975337  0.977228
# 11  0.976285  0.972578  0.982777  0.972333  0.975825  0.974169  0.976103
# ...

# %%
fit1 = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/fitnesses_10.txt', sep='\t', header=None)
fit5 = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/fitnesses_50.txt', sep='\t', header=None)
fit9 = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/fitnesses_90.txt', sep='\t', header=None)

# %%
sns.heatmap(fit1)
# Out:
# <Axes: >

# %%
sns.heatmap(fit5)
# Out:
# <Axes: >

# %%
sns.heatmap(fit9)
# Out:
# <Axes: >

# %%
fit9.round(4)
# Out:
#         0       1       2       3       4       5       6       7       8   \
# 0   0.9802  0.8709  0.7776  0.5455  0.3489  0.2126  0.1071  0.0524  0.0210
# 1   0.9445  0.9610  0.9227  0.7467  0.5321  0.3637  0.2053  0.1114  0.0512
# 2   0.8069  0.9434  0.9721  0.9072  0.7246  0.5532  0.3517  0.2115  0.1112
# 3   0.6117  0.8235  0.9100  0.9779  0.8809  0.7482  0.5381  0.3582  0.2148
# 4   0.4119  0.6389  0.7575  0.9349  0.9554  0.9000  0.7344  0.5418  0.3686
# 5   0.2465  0.4405  0.5612  0.7927  0.9242  0.9632  0.8929  0.7319  0.5620
# 6   0.1313  0.2699  0.3703  0.5960  0.7969  0.9177  0.9664  0.8830  0.7610
# 7   0.0623  0.1469  0.2179  0.3974  0.6121  0.7787  0.9301  0.9515  0.9146
# 8   0.0263  0.0711  0.1143  0.2350  0.4185  0.5891  0.7955  0.9154  0.9757
# 9   0.0099  0.0306  0.0535  0.1233  0.2547  0.3975  0.6043  0.7863  0.9239
# 10  0.0033  0.0117  0.0224  0.0574  0.1378  0.2394  0.4075  0.6027  0.7765
# ...

# %%
		catn(sim.cycle + ":" + sympatric + " " + allopatric + " " + local_adapt + " " + mean(mean_phen1) + " " + cor_temp_popmean + " " + cor_temp_ind);

# %%
la10
# Out:
#     0         1         2         3         4
# 0  10  0.976843  0.974984  0.001859  0.102483

# %%
la = pd.DataFrame()
for i in range(10,300,10):
    la1 = pd.read_csv(f'/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/_LA{i}.txt',header=None, sep = ' ')
    la1.columns = ['cycle', 'sympatric' , 'allopatric', 'local_adapt', 'cor_opt_pheno']
    la = pd.concat([la, la1])

# %%
la['']
# Out:
#    cycle  sympatric  allopatric  local_adapt  cor_opt_pheno
# 0     10   0.976843    0.974984     0.001859       0.102483
# 0     20   0.973126    0.959612     0.013514       0.331372
# 0     30   0.962873    0.910001     0.052871       0.624989
# 0     40   0.939758    0.776247     0.163512       0.840094
# 0     50   0.834889    0.368183     0.466706       0.958916
# 0     60   0.936283    0.342780     0.593503       0.980852
# 0     70   0.957899    0.334818     0.623082       0.986176
# 0     80   0.966285    0.327636     0.638649       0.988119
# 0     90   0.968036    0.325331     0.642706       0.988651
# 0    100   0.972467    0.324138     0.648329       0.990247
# 0    110   0.971062    0.323955     0.647108       0.989767
# 0    120   0.970726    0.323042     0.647684       0.989659
# 0    130   0.972473    0.323345     0.649127       0.990305
# 0    140   0.971238    0.323178     0.648060       0.989845
# 0    150   0.971386    0.323131     0.648255       0.989941
# ...

# %%
sns.scatterplot(data = la, x = 'cycle', y = 'local_adapt')
# Out:
# <Axes: xlabel='cycle', ylabel='local_adapt'>

# %%
sns.scatterplot(data = la, x = 'cycle', y = 'cor_opt_pheno')
# Out:
# <Axes: xlabel='cycle', ylabel='cor_opt_pheno'>

# %%
sns.scatterplot(data = la, x = 'cycle', y = 'cor_opt_pheno')

# %%
sns.scatterplot(data = la, x = 'cycle', y = 'local_adapt')

# %%
la90 = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/_LA90.txt',header=None, sep = ' ')
la90.columns = ['cycle', 'sympatric' , 'allopatric', 'local_adapt', 'cor_opt_pheno']

# %%
catn(sim.cycle + ":" + sympatric + " " + allopatric + " " + local_adapt + " " + cor_opt_pheno);
# Out:
#    cycle  sympatric  allopatric  local_adapt  mean_phen1  cor_opt_popmean  \
# 0     90   0.968036    0.325331     0.642706    0.015177         0.999834
#
#    cor_opt_ind
# 0     0.988651

# %%
la = pd.read_csv('/Users/tatiana/Documents/grenenet/simulations/test_slim/cline_creation/results/local_adaptation/local_adapt_78ea6d6b.txt', sep=' ',header=None)
la.columns = ['cycle', 'sympatric' , 'allopatric', 'local_adapt', 'cor_opt_pheno']

# %%
la
# Out:
#     cycle sympatric allopatric local_adapt cor_opt_pheno
# 0      10   0.97637   0.974742  0.00162804     0.0890681
# 1      20   0.97241   0.958911   0.0134982      0.325554
# 2      30  0.962164   0.909328   0.0528363      0.615847
# 3      40  0.941088   0.774408     0.16668      0.841687
# 4      50  0.863446   0.359636     0.50381      0.958607
# ..    ...       ...        ...         ...           ...
# 211    90  0.969102   0.326921    0.642182      0.989007
# 212   100       gcs        gcs         gcs           gcs
# 213   101  0.742547   0.345336    0.397212      0.836215
# 214   102  0.833236   0.336983    0.496253      0.924326
# 215   103  0.873986   0.333932    0.540054      0.947824
#
# [216 rows x 5 columns]
